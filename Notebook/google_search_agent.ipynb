# %%
from dotenv import load_dotenv
load_dotenv()
import os
import sys
import time

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_groq import ChatGroq
from langchain.agents import create_agent

# %%
llm = ChatGroq(model="openai/gpt-oss-20b")
search =GoogleSerperAPIWrapper()


search.run('Pm of india')
# Out:
# 'Narendra Modi'

# %%
agent  = create_agent(model=llm, 
                      tools=[search.run],
                      system_prompt="You are a helpful assistant that can answer questions by searching the web.", 
                      )

questions = 'What is pm of india?'

# %%
response = agent.invoke({'messages':[{'role':'user', 'content':questions}]})

# %%
response['messages'][-1].content
# Out:
# 'The current Prime Minister of India is **Narendra\u202fModi**. He has been in office since May\u202f26,\u202f2014, and was re‑elected in 2019.'
