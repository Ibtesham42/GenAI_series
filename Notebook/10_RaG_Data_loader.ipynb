# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader('../data/some_text.txt')
loader
# Out:
# c:\Users\ibtes\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\cuda\__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]

# %%
docs = loader.load()
docs
# Out:
# [Document(metadata={'source': '../data/some_text.txt'}, page_content="In today's world, coding has become an essential skill that is required in many different industries. From software development to finance to healthcare, coding plays a crucial role in solving complex problems and creating innovative solutions. By learning how to code, you can expand your skill set and open up new career opportunities.\n\nPython is a powerful programming language that has become increasingly popular in recent years. It is easy to learn and use, yet also highly versatile and capable. With its large and active community, Python has become the go-to language for many data scientists, web developers, and software engineers. By mastering Python, you can leverage its power to create sophisticated applications and data-driven solutions.\n\nDeep learning is a subfield of machine learning that focuses on training artificial neural networks to learn from data. It has revolutionized many fields, including com
# ...

# %% [markdown]
# # PDF LOADER PyPdf

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader('../data/tbltickets.pdf')
pdf = loader.load()
len(pdf)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 from langchain_community.document_loaders import PyPDFLoader
#       2 loader = PyPDFLoader('../data/tbltickets.pdf')
# ----> 3 pdf = loader.load()
#       4 len(pdf)
#
# File c:\Users\ibtes\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\document_loaders\base.py:43, in BaseLoader.load(self)
#      37 def load(self) -> list[Document]:
#      38     """Load data into `Document` objects.
#      39
#      40     Returns:
#      41         The documents.
#      42     """
# ---> 43     return list(self.lazy_load())
#
# File c:\Users\ibtes\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_community\document_loaders\pdf.py:305, in PyPDFLoader.lazy_load(self)
#     303 else:
#     304     blob = Blob.from_path(self.file_path)
# ...

# %%
# Print/show first page
print(pdf[0].page_content)

# %%
j

# %% [markdown]
# # CSV Loader

# %%
from langchain_community.document_loaders import CSVLoader
loader = CSVLoader('../data/tbltickets.csv')
csv = loader.load()

# %% [markdown]
# # Web Page LOader

# %%
from langchain_community.document_loaders import WebBaseLoader
loader = WebBaseLoader('https://en.wikipedia.org/wiki/Artificial_intelligence')
web = loader.load()

# %% [markdown]
# # Wikepedia Loader

# %%
from langchain_community.document_loaders import WikipediaLoader
loader = WikipediaLoader(query='Artificial intelligence',load_max_docs=2)
wiki = loader.load()
wiki[0].page_content[:500]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\ibtes\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_community\utilities\wikipedia.py:35, in WikipediaAPIWrapper.validate_environment(cls, values)
#      34 try:
# ---> 35     import wikipedia
#      37     lang = values.get("lang", "en")
#
# ModuleNotFoundError: No module named 'wikipedia'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 3
#       1 from langchain_community.document_loaders import WikipediaLoader
#       2 loader = WikipediaLoader(query='Artificial intelligence',load_max_docs=2)
# ----> 3 wiki = loader.load()
#       4 wiki[0].page_content[:500]
#
# ...
