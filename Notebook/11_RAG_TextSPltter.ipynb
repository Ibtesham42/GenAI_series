# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=60, chunk_overlap=50)

from langchain_community.document_loaders import TextLoader

loader = TextLoader('../data/some_text.txt')
text =loader.load()

txt_chunks = text_splitter.split_documents(text)
txt_chunks
# Out:
# [Document(metadata={'source': '../data/some_text.txt'}, page_content="In today's world, coding has become an essential skill that"),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='world, coding has become an essential skill that is'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='coding has become an essential skill that is required in'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='has become an essential skill that is required in many'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='an essential skill that is required in many different'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='skill that is required in many different industries. From'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='is required in many different industries. From software'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='in many different industries. From software development to'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='industries. From software development to finance to'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='From software development to finance to healthcare, coding'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='development to finance to healthcare, coding plays a'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='to finance to healthcare, coding plays a crucial role in'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='to healthcare, coding plays a crucial role in solving'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='coding plays a crucial role in solving complex problems and'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='a crucial role in solving complex problems and creating'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='role in solving complex problems and creating innovative'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='solving complex problems and creating innovative solutions.'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='problems and creating innovative solutions. By learning how'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='creating innovative solutions. By learning how to code, you'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='solutions. By learning how to code, you can expand your'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='By learning how to code, you can expand your skill set and'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='how to code, you can expand your skill set and open up new'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='you can expand your skill set and open up new career'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='expand your skill set and open up new career opportunities.'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='Python is a powerful programming language that has become'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='powerful programming language that has become increasingly'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='programming language that has become increasingly popular'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='language that has become increasingly popular in recent'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='that has become increasingly popular in recent years. It is'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='increasingly popular in recent years. It is easy to learn'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='popular in recent years. It is easy to learn and use, yet'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='in recent years. It is easy to learn and use, yet also'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='years. It is easy to learn and use, yet also highly'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='It is easy to learn and use, yet also highly versatile and'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='to learn and use, yet also highly versatile and capable.'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='and use, yet also highly versatile and capable. With its'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='yet also highly versatile and capable. With its large and'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='highly versatile and capable. With its large and active'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='versatile and capable. With its large and active community,'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='and capable. With its large and active community, Python'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='With its large and active community, Python has become the'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='large and active community, Python has become the go-to'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='and active community, Python has become the go-to language'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='community, Python has become the go-to language for many'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='Python has become the go-to language for many data'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='has become the go-to language for many data scientists, web'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='go-to language for many data scientists, web developers,'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='for many data scientists, web developers, and software'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='data scientists, web developers, and software engineers. By'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='web developers, and software engineers. By mastering'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='developers, and software engineers. By mastering Python,'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='and software engineers. By mastering Python, you can'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='software engineers. By mastering Python, you can leverage'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='engineers. By mastering Python, you can leverage its power'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='By mastering Python, you can leverage its power to create'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='Python, you can leverage its power to create sophisticated'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='can leverage its power to create sophisticated applications'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='its power to create sophisticated applications and'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='power to create sophisticated applications and data-driven'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='sophisticated applications and data-driven solutions.'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='Deep learning is a subfield of machine learning that'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='learning is a subfield of machine learning that focuses on'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='is a subfield of machine learning that focuses on training'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='of machine learning that focuses on training artificial'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='learning that focuses on training artificial neural'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='that focuses on training artificial neural networks to'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='focuses on training artificial neural networks to learn'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='on training artificial neural networks to learn from data.'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='artificial neural networks to learn from data. It has'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='neural networks to learn from data. It has revolutionized'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='to learn from data. It has revolutionized many fields,'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='from data. It has revolutionized many fields, including'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='It has revolutionized many fields, including computer'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='revolutionized many fields, including computer vision,'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='many fields, including computer vision, natural language'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='including computer vision, natural language processing, and'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='computer vision, natural language processing, and speech'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='natural language processing, and speech recognition. By'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='language processing, and speech recognition. By using deep'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='processing, and speech recognition. By using deep learning'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='and speech recognition. By using deep learning techniques,'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='recognition. By using deep learning techniques, you can'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='By using deep learning techniques, you can create models'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='deep learning techniques, you can create models that are'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='techniques, you can create models that are capable of'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='you can create models that are capable of recognizing'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='can create models that are capable of recognizing patterns,'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='models that are capable of recognizing patterns, making'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='are capable of recognizing patterns, making predictions,'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='of recognizing patterns, making predictions, and generating'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='patterns, making predictions, and generating insights that'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='making predictions, and generating insights that can inform'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='and generating insights that can inform decision-making.'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='One of the key benefits of deep learning is its ability to'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='key benefits of deep learning is its ability to work with'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='of deep learning is its ability to work with large and'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='learning is its ability to work with large and complex'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='is its ability to work with large and complex datasets.'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='ability to work with large and complex datasets. This is'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='to work with large and complex datasets. This is important'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='large and complex datasets. This is important because we'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='complex datasets. This is important because we are'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='datasets. This is important because we are generating more'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='This is important because we are generating more data than'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='because we are generating more data than ever before, and'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='are generating more data than ever before, and traditional'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='more data than ever before, and traditional statistical'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='than ever before, and traditional statistical methods may'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='before, and traditional statistical methods may not be'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='and traditional statistical methods may not be sufficient'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='statistical methods may not be sufficient to extract'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='methods may not be sufficient to extract insights from this'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='not be sufficient to extract insights from this data. Deep'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='to extract insights from this data. Deep learning allows us'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='insights from this data. Deep learning allows us to train'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='from this data. Deep learning allows us to train models'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='data. Deep learning allows us to train models that can'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='Deep learning allows us to train models that can identify'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='allows us to train models that can identify patterns and'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='train models that can identify patterns and relationships'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='that can identify patterns and relationships within this'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='identify patterns and relationships within this data, even'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='patterns and relationships within this data, even if they'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='and relationships within this data, even if they are not'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='within this data, even if they are not obvious to the human'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='data, even if they are not obvious to the human eye.'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='Another advantage of deep learning is its ability to handle'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='of deep learning is its ability to handle unstructured'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='learning is its ability to handle unstructured data, such'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='is its ability to handle unstructured data, such as images,'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='to handle unstructured data, such as images, audio, and'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='unstructured data, such as images, audio, and text. This is'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='data, such as images, audio, and text. This is important'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='as images, audio, and text. This is important because much'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='audio, and text. This is important because much of the data'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='text. This is important because much of the data that we'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='is important because much of the data that we generate is'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='because much of the data that we generate is in this form.'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='of the data that we generate is in this form. By using deep'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='that we generate is in this form. By using deep learning'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='is in this form. By using deep learning techniques, we can'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='form. By using deep learning techniques, we can extract'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='using deep learning techniques, we can extract meaningful'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='learning techniques, we can extract meaningful insights'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='techniques, we can extract meaningful insights from this'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='we can extract meaningful insights from this unstructured'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='meaningful insights from this unstructured data, such as'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='insights from this unstructured data, such as identifying'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='from this unstructured data, such as identifying objects in'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='unstructured data, such as identifying objects in images or'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='data, such as identifying objects in images or extracting'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='as identifying objects in images or extracting sentiment'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='objects in images or extracting sentiment from text.'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='Python is an ideal language for deep learning because it'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='is an ideal language for deep learning because it offers a'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='language for deep learning because it offers a wide range'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='for deep learning because it offers a wide range of'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='deep learning because it offers a wide range of libraries'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='because it offers a wide range of libraries and frameworks'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='offers a wide range of libraries and frameworks that make'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='wide range of libraries and frameworks that make it easy to'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='of libraries and frameworks that make it easy to build and'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='and frameworks that make it easy to build and train neural'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='that make it easy to build and train neural networks. Some'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='it easy to build and train neural networks. Some of the'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='to build and train neural networks. Some of the most'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='build and train neural networks. Some of the most popular'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='train neural networks. Some of the most popular deep'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='neural networks. Some of the most popular deep learning'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='networks. Some of the most popular deep learning libraries'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='Some of the most popular deep learning libraries in Python'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='most popular deep learning libraries in Python include'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='deep learning libraries in Python include TensorFlow,'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='learning libraries in Python include TensorFlow, PyTorch,'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='libraries in Python include TensorFlow, PyTorch, and Keras.'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='in Python include TensorFlow, PyTorch, and Keras. These'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='include TensorFlow, PyTorch, and Keras. These libraries'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='TensorFlow, PyTorch, and Keras. These libraries allow you'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='PyTorch, and Keras. These libraries allow you to build'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='and Keras. These libraries allow you to build complex'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='Keras. These libraries allow you to build complex models'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='These libraries allow you to build complex models with'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='libraries allow you to build complex models with ease, and'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='allow you to build complex models with ease, and they offer'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='to build complex models with ease, and they offer a range'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='complex models with ease, and they offer a range of'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='models with ease, and they offer a range of pre-trained'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='with ease, and they offer a range of pre-trained models'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='and they offer a range of pre-trained models that you can'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='offer a range of pre-trained models that you can use to'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='a range of pre-trained models that you can use to jumpstart'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='pre-trained models that you can use to jumpstart your own'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='models that you can use to jumpstart your own projects.'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='Deep learning has many practical applications across a wide'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='has many practical applications across a wide range of'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='practical applications across a wide range of industries.'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='applications across a wide range of industries. In'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='across a wide range of industries. In healthcare, deep'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='a wide range of industries. In healthcare, deep learning'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='range of industries. In healthcare, deep learning models'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='industries. In healthcare, deep learning models can be used'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='In healthcare, deep learning models can be used to identify'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='deep learning models can be used to identify tumors in'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='learning models can be used to identify tumors in medical'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='models can be used to identify tumors in medical images or'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='be used to identify tumors in medical images or to analyze'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='identify tumors in medical images or to analyze patient'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='tumors in medical images or to analyze patient data to'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='in medical images or to analyze patient data to identify'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='images or to analyze patient data to identify potential'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='or to analyze patient data to identify potential health'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='analyze patient data to identify potential health risks. In'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='data to identify potential health risks. In finance, deep'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='identify potential health risks. In finance, deep learning'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='potential health risks. In finance, deep learning models'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='health risks. In finance, deep learning models can be used'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='In finance, deep learning models can be used to predict'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='deep learning models can be used to predict stock prices or'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='models can be used to predict stock prices or to identify'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='be used to predict stock prices or to identify fraudulent'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='stock prices or to identify fraudulent transactions. In'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='or to identify fraudulent transactions. In manufacturing,'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='fraudulent transactions. In manufacturing, deep learning'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='transactions. In manufacturing, deep learning models can be'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='In manufacturing, deep learning models can be used to'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='deep learning models can be used to optimize production'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='models can be used to optimize production processes and'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='can be used to optimize production processes and improve'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='used to optimize production processes and improve quality'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='optimize production processes and improve quality control.'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='Deep learning also has important implications for the'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='learning also has important implications for the future of'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='also has important implications for the future of work. As'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='important implications for the future of work. As more'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='implications for the future of work. As more tasks become'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='for the future of work. As more tasks become automated, the'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='of work. As more tasks become automated, the demand for'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='As more tasks become automated, the demand for workers who'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='become automated, the demand for workers who can design and'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='the demand for workers who can design and train deep'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='demand for workers who can design and train deep learning'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='workers who can design and train deep learning models will'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='can design and train deep learning models will only'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='design and train deep learning models will only increase.'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='train deep learning models will only increase. By learning'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='learning models will only increase. By learning how to work'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='will only increase. By learning how to work with deep'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='only increase. By learning how to work with deep learning'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='By learning how to work with deep learning models, you can'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='how to work with deep learning models, you can position'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='work with deep learning models, you can position yourself'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='deep learning models, you can position yourself for a'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='learning models, you can position yourself for a career in'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='models, you can position yourself for a career in one of'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='you can position yourself for a career in one of the'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='yourself for a career in one of the fastest-growing fields'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='for a career in one of the fastest-growing fields in'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='career in one of the fastest-growing fields in technology.'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='Python and deep learning are also important for research.'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='deep learning are also important for research. With their'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='are also important for research. With their ability to work'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='for research. With their ability to work with large and'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='With their ability to work with large and complex datasets,'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='ability to work with large and complex datasets, they have'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='work with large and complex datasets, they have become'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='with large and complex datasets, they have become essential'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='and complex datasets, they have become essential tools for'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='datasets, they have become essential tools for scientists'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='they have become essential tools for scientists in fields'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='become essential tools for scientists in fields such as'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='essential tools for scientists in fields such as astronomy,'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='tools for scientists in fields such as astronomy, biology,'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='scientists in fields such as astronomy, biology, and'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='in fields such as astronomy, biology, and physics. By using'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='such as astronomy, biology, and physics. By using deep'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='as astronomy, biology, and physics. By using deep learning'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='biology, and physics. By using deep learning models,'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='and physics. By using deep learning models, scientists can'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='By using deep learning models, scientists can analyze large'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='learning models, scientists can analyze large amounts of'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='models, scientists can analyze large amounts of data and'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='scientists can analyze large amounts of data and extract'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='can analyze large amounts of data and extract insights that'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='large amounts of data and extract insights that were'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='amounts of data and extract insights that were previously'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='data and extract insights that were previously impossible'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='extract insights that were previously impossible to obtain.'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='In conclusion, coding, Python, and deep learning are all'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='coding, Python, and deep learning are all essential tools'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='Python, and deep learning are all essential tools for'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='and deep learning are all essential tools for anyone who'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='learning are all essential tools for anyone who wants to'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='are all essential tools for anyone who wants to work in'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='essential tools for anyone who wants to work in technology'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='tools for anyone who wants to work in technology or'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='for anyone who wants to work in technology or research. By'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='who wants to work in technology or research. By learning'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='to work in technology or research. By learning how to code,'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='technology or research. By learning how to code, you can'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='or research. By learning how to code, you can expand your'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='By learning how to code, you can expand your skill set and'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='how to code, you can expand your skill set and open up new'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='you can expand your skill set and open up new career'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='expand your skill set and open up new career opportunities.'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='skill set and open up new career opportunities. By learning'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='and open up new career opportunities. By learning Python,'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='up new career opportunities. By learning Python, you can'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='career opportunities. By learning Python, you can leverage'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='By learning Python, you can leverage its power to create'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='Python, you can leverage its power to create sophisticated'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='can leverage its power to create sophisticated applications'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='its power to create sophisticated applications and'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='power to create sophisticated applications and data-driven'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='sophisticated applications and data-driven solutions. And'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='applications and data-driven solutions. And by mastering'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='and data-driven solutions. And by mastering deep learning,'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='solutions. And by mastering deep learning, you can build'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='And by mastering deep learning, you can build models that'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='deep learning, you can build models that can identify'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='learning, you can build models that can identify patterns'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='you can build models that can identify patterns and'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='build models that can identify patterns and relationships'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='that can identify patterns and relationships within complex'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='patterns and relationships within complex datasets,'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='and relationships within complex datasets, enabling you to'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='within complex datasets, enabling you to extract insights'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='datasets, enabling you to extract insights and make'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='enabling you to extract insights and make informed'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='you to extract insights and make informed decisions.'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='Digitalsreeni is a YouTube channel that is dedicated to'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='is a YouTube channel that is dedicated to providing'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='YouTube channel that is dedicated to providing high-quality'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='that is dedicated to providing high-quality Python'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='is dedicated to providing high-quality Python tutorials'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='to providing high-quality Python tutorials with a focus on'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='high-quality Python tutorials with a focus on image'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='Python tutorials with a focus on image analysis using deep'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='with a focus on image analysis using deep learning. The'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='focus on image analysis using deep learning. The channel is'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='analysis using deep learning. The channel is run by'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='using deep learning. The channel is run by Sreenivas Sarwar'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='learning. The channel is run by Sreenivas Sarwar Anik, a'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='The channel is run by Sreenivas Sarwar Anik, a data'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='channel is run by Sreenivas Sarwar Anik, a data scientist'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='is run by Sreenivas Sarwar Anik, a data scientist with more'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='Sreenivas Sarwar Anik, a data scientist with more than 12'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='Sarwar Anik, a data scientist with more than 12 years of'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='a data scientist with more than 12 years of experience in'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='with more than 12 years of experience in the field of data'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='than 12 years of experience in the field of data analytics'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='of experience in the field of data analytics and machine'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='in the field of data analytics and machine learning. He is'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='of data analytics and machine learning. He is a passionate'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='and machine learning. He is a passionate teacher who is'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='learning. He is a passionate teacher who is committed to'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='He is a passionate teacher who is committed to helping'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='a passionate teacher who is committed to helping others'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='teacher who is committed to helping others learn and'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='who is committed to helping others learn and develop their'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='to helping others learn and develop their skills in this'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='others learn and develop their skills in this exciting and'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='and develop their skills in this exciting and rapidly'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='develop their skills in this exciting and rapidly growing'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='their skills in this exciting and rapidly growing field.'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='The tutorials on Digitalsreeni cover a wide range of topics'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='on Digitalsreeni cover a wide range of topics related to'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='cover a wide range of topics related to image analysis'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='a wide range of topics related to image analysis using deep'),
# ...
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='learning, including object detection, image classification,'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='including object detection, image classification, and image'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='detection, image classification, and image segmentation.'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content="image classification, and image segmentation. Sreeni's"),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content="classification, and image segmentation. Sreeni's clear and"),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content="and image segmentation. Sreeni's clear and concise"),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content="image segmentation. Sreeni's clear and concise explanations"),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content="Sreeni's clear and concise explanations of complex concepts"),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='and concise explanations of complex concepts make his'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='concise explanations of complex concepts make his tutorials'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='of complex concepts make his tutorials accessible to both'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='concepts make his tutorials accessible to both beginners'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='make his tutorials accessible to both beginners and'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='his tutorials accessible to both beginners and advanced'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='accessible to both beginners and advanced learners. He also'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='to both beginners and advanced learners. He also provides'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='beginners and advanced learners. He also provides practical'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='and advanced learners. He also provides practical examples'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='learners. He also provides practical examples and'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='He also provides practical examples and demonstrations that'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='practical examples and demonstrations that help students'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='examples and demonstrations that help students understand'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='and demonstrations that help students understand how to'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='that help students understand how to apply the concepts'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='students understand how to apply the concepts they are'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='understand how to apply the concepts they are learning to'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='how to apply the concepts they are learning to real-world'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='the concepts they are learning to real-world problems.'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='One of the most valuable aspects of Digitalsreeni is that'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='most valuable aspects of Digitalsreeni is that it focuses'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='aspects of Digitalsreeni is that it focuses on using Python'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='Digitalsreeni is that it focuses on using Python as the'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='is that it focuses on using Python as the programming'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='it focuses on using Python as the programming language for'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='on using Python as the programming language for deep'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='using Python as the programming language for deep learning.'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='as the programming language for deep learning. Python is'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='programming language for deep learning. Python is widely'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='language for deep learning. Python is widely used in the'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='for deep learning. Python is widely used in the field of'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='learning. Python is widely used in the field of data'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='Python is widely used in the field of data science and'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='is widely used in the field of data science and machine'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='used in the field of data science and machine learning, and'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='field of data science and machine learning, and it has a'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='data science and machine learning, and it has a large and'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='and machine learning, and it has a large and active'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='machine learning, and it has a large and active community'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='learning, and it has a large and active community of'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='and it has a large and active community of developers who'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='a large and active community of developers who contribute'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='and active community of developers who contribute to its'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='community of developers who contribute to its development.'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='of developers who contribute to its development. By'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='developers who contribute to its development. By learning'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='who contribute to its development. By learning how to use'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='to its development. By learning how to use Python for image'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='By learning how to use Python for image analysis using deep'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='how to use Python for image analysis using deep learning'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='Python for image analysis using deep learning techniques,'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='image analysis using deep learning techniques, students can'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='using deep learning techniques, students can acquire skills'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='learning techniques, students can acquire skills that are'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='techniques, students can acquire skills that are in high'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='students can acquire skills that are in high demand in the'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='can acquire skills that are in high demand in the job'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='acquire skills that are in high demand in the job market.'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='In addition to Python tutorials, Digitalsreeni also'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='addition to Python tutorials, Digitalsreeni also provides'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='to Python tutorials, Digitalsreeni also provides tutorials'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='tutorials, Digitalsreeni also provides tutorials on popular'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='Digitalsreeni also provides tutorials on popular deep'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='also provides tutorials on popular deep learning libraries'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='tutorials on popular deep learning libraries such as'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='on popular deep learning libraries such as TensorFlow and'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='deep learning libraries such as TensorFlow and Keras. These'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='libraries such as TensorFlow and Keras. These libraries are'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='such as TensorFlow and Keras. These libraries are essential'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='and Keras. These libraries are essential tools for anyone'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='These libraries are essential tools for anyone working in'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='are essential tools for anyone working in the field of'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='tools for anyone working in the field of computer vision'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='anyone working in the field of computer vision and image'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='working in the field of computer vision and image analysis,'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='the field of computer vision and image analysis, and'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content="field of computer vision and image analysis, and Sreeni's"),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content="computer vision and image analysis, and Sreeni's tutorials"),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content="vision and image analysis, and Sreeni's tutorials provide a"),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content="image analysis, and Sreeni's tutorials provide a clear and"),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content="and Sreeni's tutorials provide a clear and practical"),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='tutorials provide a clear and practical introduction to'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='provide a clear and practical introduction to their use.'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='a clear and practical introduction to their use. Overall,'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='practical introduction to their use. Overall, Digitalsreeni'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='introduction to their use. Overall, Digitalsreeni is an'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='to their use. Overall, Digitalsreeni is an amazing resource'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='Overall, Digitalsreeni is an amazing resource for anyone'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='Digitalsreeni is an amazing resource for anyone looking to'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='is an amazing resource for anyone looking to learn about'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='resource for anyone looking to learn about image analysis'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='for anyone looking to learn about image analysis using deep'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='looking to learn about image analysis using deep learning'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='learn about image analysis using deep learning techniques'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='image analysis using deep learning techniques in Python.'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='using deep learning techniques in Python. With its clear'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='learning techniques in Python. With its clear explanations,'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='in Python. With its clear explanations, practical examples,'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='With its clear explanations, practical examples, and focus'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='clear explanations, practical examples, and focus on'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='explanations, practical examples, and focus on real-world'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='practical examples, and focus on real-world problems, it is'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='examples, and focus on real-world problems, it is a'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='and focus on real-world problems, it is a valuable asset'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='on real-world problems, it is a valuable asset for anyone'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='problems, it is a valuable asset for anyone who wants to'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='it is a valuable asset for anyone who wants to develop'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='a valuable asset for anyone who wants to develop their'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='asset for anyone who wants to develop their skills in this'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='anyone who wants to develop their skills in this exciting'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='wants to develop their skills in this exciting and rapidly'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='develop their skills in this exciting and rapidly growing'),
#  Document(metadata={'source': '../data/some_text.txt'}, page_content='their skills in this exciting and rapidly growing field.')]
